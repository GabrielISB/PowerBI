# %% [markdown]
# # Power BI Installation

# %% [markdown]
# In this document we will be using Power BI desktop, however, you could also use Power BI Online but we strongly recommend the desktop version for this workshop.
# 1. Here we are going to install Power BI for both Apple and Windows. First go to the app store. [Windows](https://powerbi.microsoft.com/es-es/downloads/) - [Mac](https://apps.apple.com/mx/app/microsoft-power-bi/id929738808) and download the application
#
#
# [MAC USERS VIDEO FOR INSTALL](https://www.youtube.com/watch?v=qUpqtWEOG40)
#
#
# EDIT: THE VERSION FOR MAC MIGHT NOT WORK THEREFORE YOU SHOULD USE THE ONLINE VERSION (SEE BELOW)

# %% [markdown]
# **Microsoft:**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Apple:**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2. Once you have finally installed Power BI on your computer, the next step is to open it and log in.
# You will find on the right top corner a button to log in. Make sure you log in with the institutional email. _For example 65456@upy.edu.mx_

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# then:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Finally:![image.png](attachment:image.png)

# %% [markdown]
# # ONLINE VERSION (FOR MAC USERS)

# %% [markdown]
# 1. [Link for the ONLINE VERSION](https://powerbi.microsoft.com/en-us/getting-started-with-power-bi/)

# %% [markdown]
# Click on "Try For Free"
# ![image.png](attachment:image.png)

# %% [markdown]
# Sign up with your UPY Account
# ![image.png](attachment:image.png)

# %% [markdown]
# Now you should have your online version
# ![image.png](attachment:image.png)
